# %%
import torch
import torch.nn as nn
import torchvision.models as models
import json
import h5py
from utils import img_data_2_mini_batch, imgs2batch
import numpy as np
import matplotlib.pyplot as plt
import torch.utils.data as Data
from torchvision import transforms
from PIL import Image
import torch.nn.functional as F
import os


# %matplotlib inline
# %reload_ext autoreload

# %%
base_f = 'cocoqa_data_prepro_'
base_n = '2771'
base_fn = base_f + base_n




transform = transforms.Compose([
    transforms.RandomCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406),
                         (0.229, 0.224, 0.225))])

# %%
val_data_h5 = h5py.File(base_fn+'.h5', 'r')

# %%
val_data_json = json.load(open(base_fn+'.json', 'r'))
# pad fix
itow = val_data_json['ix_to_word']

wtoi = {iv: ik for ik,iv in itow.items()}
old_pad = wtoi['<pad>']
wtoi['<pad_fix>'] = old_pad
wtoi['<pad>'] = '0'
itow[old_pad] = '<pad_fix>'
itow['0'] = '<pad>'

# print wtoi['<pad>']
# print itow['0']
# print wtoi['<pad_fix>']

assert(wtoi['<pad>'] == '0')
assert(itow['0'] == '<pad>')


# print val_data_json.keys()
# print val_data_h5.keys()

# %%
itoa = val_data_json['ix_to_ans']
# print len(itoa)
# print itoa['38']
# print itoa
unique_img_val = val_data_json['unique_img_val']
ques_val = val_data_h5['ques_val'][:]
ans_val = val_data_h5['ans_val'][:]
question_id_val = val_data_h5['question_id_val'][:]
img_pos_val = val_data_h5['img_pos_val'][:]
images = np.array(imgs2batch(unique_img_val, img_pos_val, transform=transform))
ques_val = np.array(ques_val)
ans_val = np.array(ans_val).reshape((-1, 1))

# print images.shape

images = torch.from_numpy(images)
ques_val = torch.from_numpy(ques_val)
ans_val = torch.from_numpy(ans_val)

# print images.size()
# print ques_val.size()
# print ans_val.size()
# print(ans_val.shape)

# %%
# for i in range(ques_val.size(1)):
#     print ' '.join(filter(lambda kx: kx!='<pad>',(map(lambda wr: itow[str(wr)], ques_val[i].detach().numpy().tolist()))))
#     print ' '.join(map(lambda wr: itoa[str(wr)], ans_val[i].detach().numpy().tolist()))

# %%
ques_ans_val = torch.cat((ques_val, ans_val), dim=1)
BATCH_SIZE = 100
split_point = int(0.1 * ques_ans_val.size(0)) # split 10% for testing

ques_ans_splits = torch.split(ques_ans_val, split_point, dim=0)
images_splits = torch.split(images, split_point, dim=0)

ques_ans_test = ques_ans_splits[0]
ques_ans_train = torch.cat(ques_ans_splits[1:], dim=0)

images_test = images_splits[0]
images_train = torch.cat(images_splits[1:], dim=0)

# should be (torch.Size([TRAIN_SIZE, 3, 224, 224]), torch.Size([TRAIN_SIZE, MAX_LENGTH]))
print(images_train.size(), ques_ans_train.size()) 
# should be (torch.Size([TEST_SIZEZ, 3, 224, 224]), torch.Size([TEST_SIZE, MAX_LENGTH]))
print(images_test.size(), ques_ans_test.size())

train_dataset=Data.TensorDataset(images_train, ques_ans_train)
test_dataset=Data.TensorDataset(images_test, ques_ans_test)
train_loader = Data.DataLoader(
        dataset=train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True
    )

test_loader = Data.DataLoader(
        dataset=test_dataset,
        batch_size=100,
        shuffle=False
    )
# Out:
# torch.Size([2494, 3, 224, 224]) torch.Size([2494, 27])
# torch.Size([277, 3, 224, 224]) torch.Size([277, 27])

# %%
from naive import Enc, Dec
device = torch.device('cuda')
embed_size = 256
hidden_size = 256
ques_vocab_size = len(itow)
ans_vocab_size = len(itoa)+1
num_layers = 1

# print 'embed',embed_size,'hidden',hidden_size,'ques_vocab',ques_vocab_size, 'ans_vocab',ans_vocab_size
encoder = Enc(embed_size).to(device)
decoder = Dec(embed_size, hidden_size, ques_vocab_size, ans_vocab_size, num_layers).cuda()
# encoder.double()

# %%
# optimizer and loss
params = list(decoder.parameters()) + list(encoder.linear.parameters()) + list(encoder.bn.parameters())
optimizer = torch.optim.Adam(params,lr=0.005)
encoder.train()
decoder.train()
# start your train
lossList = []
accList = []
for epoch in range(100):
    for i, (images, img_ans_val) in enumerate(train_loader):
        ques, ans = torch.split(img_ans_val, 26,dim=1)
        # images of shape [batch, 3, 256, 256]
        # ques of shape [batch, 26]
        # ans of shape [batch, 1]

        lengths = []
        for qix in ques:
            for iy in range(len(qix)):
                if (qix[iy]==0):
                    lengths.append(iy)
                    break;
        tups = []
        for ix in range(ques.size(0)):
            row = ques[ix,:]
            length = lengths[ix]
            image_i = images[ix,:]
            ans_i = ans[ix,:]
            tup = (row, length, image_i, ans_i)
            tups.append(tup)

        sorted_tuples = sorted(tups, key=lambda tup: tup[1], reverse=True)
        questions = torch.stack(list(map(lambda tup: tup[0], sorted_tuples)))
        images = torch.stack(list(map(lambda tup: tup[2], sorted_tuples)))
        answers = torch.stack(list(map(lambda tup: tup[3], sorted_tuples)))
        lengths = list(map(lambda tup: tup[1], sorted_tuples))
        
#         print 'images', images.size()
#         print 'img_ans_val', img_ans_val.size()
#         print 'questions', questions.size()
#         print 'answers', answers.size()
#         print 'lengths', lengths
    
        images = images.to(device)
        questions = questions.to(device).long()
        features = encoder(images).cuda()
#         print '[OUT] features',features.size()
        output = decoder(features, questions, lengths).cuda()
        answers = answers.reshape((-1)).long().cuda()
#         print '[OUT] output ', output.size()
#         print '[OUT] answers ', answers.size()
        loss = F.nll_loss(output, answers)

        # copy here
        lossList.append(loss.item())
        
        _, pred = torch.max(output, dim=1)
        
        correct = pred.eq(answers.long().view_as(pred)).sum()
        acc = float(correct) / float(BATCH_SIZE)
        
        accList.append(acc)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if i % 5 == 0: 
            print('epoch',epoch,'#', i, 'loss:', loss.item(), 'acc:', acc, 'correct:', correct)


encoder.eval()
decoder.eval()

print(' ')
print(' TEST ')
print(' ')

lossList_test = []
accList_test = []

for i, (images, img_ans_val) in enumerate(test_loader):
        ques, ans = torch.split(img_ans_val, 26,dim=1)
        # images of shape [batch, 3, 256, 256]
        # ques of shape [batch, 26]
        # ans of shape [batch, 1]

        lengths = []
        for qix in ques:
            for iy in range(len(qix)):
                if (qix[iy]==0):
                    lengths.append(iy)
                    break;
        tups = []
        for ix in range(ques.size(0)):
            row = ques[ix,:]
            length = lengths[ix]
            image_i = images[ix,:]
            ans_i = ans[ix,:]
            tup = (row, length, image_i, ans_i)
            tups.append(tup)

        sorted_tuples = sorted(tups, key=lambda tup: tup[1], reverse=True)
        questions = torch.stack(list(map(lambda tup: tup[0], sorted_tuples)))
        images = torch.stack(list(map(lambda tup: tup[2], sorted_tuples)))
        answers = torch.stack(list(map(lambda tup: tup[3], sorted_tuples)))
        lengths = list(map(lambda tup: tup[1], sorted_tuples))

        images = images.to(device)
        questions = questions.to(device).long()
        features = encoder(images).cuda()
#         print '[OUT] features',features.size()
        output = decoder(features, questions, lengths).cuda()
        answers = answers.reshape((-1)).long().cuda()
        loss = F.nll_loss(output, answers)

        # copy here
        lossList_test.append(loss.item())
        
        _, pred = torch.max(output, dim=1)
        
        correct = pred.eq(answers.long().view_as(pred)).sum()
        acc = float(correct) / float(5)
        
        accList_test.append(acc)
        
        if i % 5 == 0: 
            print('epoch',epoch,'#', i, 'loss:', loss.item(), 'acc:', acc, 'correct:', correct)
# Out:
# epoch 0 # 0 loss: 6.316684722900391 acc: 0.0 correct: tensor(0, device='cuda:0')
# epoch 0 # 5 loss: 5.720936298370361 acc: 0.26 correct: tensor(26, device='cuda:0')
# epoch 0 # 10 loss: 4.423179626464844 acc: 0.18 correct: tensor(18, device='cuda:0')
# epoch 0 # 15 loss: 4.270138263702393 acc: 0.2 correct: tensor(20, device='cuda:0')
# epoch 0 # 20 loss: 4.134198188781738 acc: 0.17 correct: tensor(17, device='cuda:0')
# epoch 1 # 0 loss: 3.411949872970581 acc: 0.17 correct: tensor(17, device='cuda:0')
# epoch 1 # 5 loss: 3.284688711166382 acc: 0.2 correct: tensor(20, device='cuda:0')
# epoch 1 # 10 loss: 3.3467824459075928 acc: 0.29 correct: tensor(29, device='cuda:0')
# epoch 1 # 15 loss: 3.4165940284729004 acc: 0.22 correct: tensor(22, device='cuda:0')
# epoch 1 # 20 loss: 3.5993895530700684 acc: 0.16 correct: tensor(16, device='cuda:0')
# epoch 2 # 0 loss: 3.390714645385742 acc: 0.15 correct: tensor(15, device='cuda:0')
# epoch 2 # 5 loss: 3.242945671081543 acc: 0.21 correct: tensor(21, device='cuda:0')
# epoch 2 # 10 loss: 3.033818244934082 acc: 0.28 correct: tensor(28, device='cuda:0')
# epoch 2 # 15 loss: 3.2554967403411865 acc: 0.18 correct: tensor(18, device='cuda:0')
# epoch 2 # 20 loss: 3.2305736541748047 acc: 0.2 correct: tensor(20, device='cuda:0')
# epoch 3 # 0 loss: 2.772751569747925 acc: 0.33 correct: tensor(33, device='cuda:0')
# epoch 3 # 5 loss: 3.212686061859131 acc: 0.22 correct: tensor(22, device='cuda:0')
# epoch 3 # 10 loss: 3.1943166255950928 acc: 0.21 correct: tensor(21, device='cuda:0')
# epoch 3 # 15 loss: 2.987678289413452 acc: 0.22 correct: tensor(22, device='cuda:0')
# epoch 3 # 20 loss: 3.0100698471069336 acc: 0.23 correct: tensor(23, device='cuda:0')
# epoch 4 # 0 loss: 2.714078426361084 acc: 0.29 correct: tensor(29, device='cuda:0')
# epoch 4 # 5 loss: 2.6032111644744873 acc: 0.29 correct: tensor(29, device='cuda:0')
# epoch 4 # 10 loss: 2.7985599040985107 acc: 0.31 correct: tensor(31, device='cuda:0')
# epoch 4 # 15 loss: 2.9632785320281982 acc: 0.31 correct: tensor(31, device='cuda:0')
# epoch 4 # 20 loss: 3.1557865142822266 acc: 0.19 correct: tensor(19, device='cuda:0')
# epoch 5 # 0 loss: 2.519747734069824 acc: 0.26 correct: tensor(26, device='cuda:0')
# epoch 5 # 5 loss: 2.7628610134124756 acc: 0.27 correct: tensor(27, device='cuda:0')
# epoch 5 # 10 loss: 2.6843860149383545 acc: 0.24 correct: tensor(24, device='cuda:0')
# epoch 5 # 15 loss: 2.8355748653411865 acc: 0.33 correct: tensor(33, device='cuda:0')
# epoch 5 # 20 loss: 2.726008415222168 acc: 0.24 correct: tensor(24, device='cuda:0')
# epoch 6 # 0 loss: 2.6056406497955322 acc: 0.33 correct: tensor(33, device='cuda:0')
# epoch 6 # 5 loss: 2.5922141075134277 acc: 0.26 correct: tensor(26, device='cuda:0')
# epoch 6 # 10 loss: 2.50620174407959 acc: 0.27 correct: tensor(27, device='cuda:0')
# epoch 6 # 15 loss: 2.7422308921813965 acc: 0.27 correct: tensor(27, device='cuda:0')
# epoch 6 # 20 loss: 2.6787216663360596 acc: 0.26 correct: tensor(26, device='cuda:0')
# epoch 7 # 0 loss: 2.621039628982544 acc: 0.27 correct: tensor(27, device='cuda:0')
# epoch 7 # 5 loss: 2.482624053955078 acc: 0.23 correct: tensor(23, device='cuda:0')
# epoch 7 # 10 loss: 2.4361677169799805 acc: 0.27 correct: tensor(27, device='cuda:0')
# epoch 7 # 15 loss: 2.7875049114227295 acc: 0.23 correct: tensor(23, device='cuda:0')
# epoch 7 # 20 loss: 2.781827449798584 acc: 0.19 correct: tensor(19, device='cuda:0')
# epoch 8 # 0 loss: 2.3410253524780273 acc: 0.24 correct: tensor(24, device='cuda:0')
# epoch 8 # 5 loss: 2.172152519226074 acc: 0.37 correct: tensor(37, device='cuda:0')
# epoch 8 # 10 loss: 2.372145652770996 acc: 0.25 correct: tensor(25, device='cuda:0')
# epoch 8 # 15 loss: 2.4717600345611572 acc: 0.23 correct: tensor(23, device='cuda:0')
# epoch 8 # 20 loss: 2.469571113586426 acc: 0.29 correct: tensor(29, device='cuda:0')
# epoch 9 # 0 loss: 2.0967819690704346 acc: 0.35 correct: tensor(35, device='cuda:0')
# epoch 9 # 5 loss: 2.246284246444702 acc: 0.37 correct: tensor(37, device='cuda:0')
# epoch 9 # 10 loss: 2.174743890762329 acc: 0.34 correct: tensor(34, device='cuda:0')
# epoch 9 # 15 loss: 2.179410219192505 acc: 0.33 correct: tensor(33, device='cuda:0')
# epoch 9 # 20 loss: 2.406231641769409 acc: 0.28 correct: tensor(28, device='cuda:0')
# epoch 10 # 0 loss: 1.9583796262741089 acc: 0.4 correct: tensor(40, device='cuda:0')
# epoch 10 # 5 loss: 1.974134922027588 acc: 0.38 correct: tensor(38, device='cuda:0')
# epoch 10 # 10 loss: 2.360579490661621 acc: 0.21 correct: tensor(21, device='cuda:0')
# epoch 10 # 15 loss: 2.2607548236846924 acc: 0.28 correct: tensor(28, device='cuda:0')
# epoch 10 # 20 loss: 2.2555527687072754 acc: 0.23 correct: tensor(23, device='cuda:0')
# epoch 11 # 0 loss: 2.0920701026916504 acc: 0.31 correct: tensor(31, device='cuda:0')
# epoch 11 # 5 loss: 1.9010928869247437 acc: 0.42 correct: tensor(42, device='cuda:0')
# epoch 11 # 10 loss: 2.142878532409668 acc: 0.33 correct: tensor(33, device='cuda:0')
# epoch 11 # 15 loss: 2.3131825923919678 acc: 0.25 correct: tensor(25, device='cuda:0')
# epoch 11 # 20 loss: 2.198014736175537 acc: 0.31 correct: tensor(31, device='cuda:0')
# epoch 12 # 0 loss: 2.032000780105591 acc: 0.3 correct: tensor(30, device='cuda:0')
# epoch 12 # 5 loss: 1.9837193489074707 acc: 0.4 correct: tensor(40, device='cuda:0')
# epoch 12 # 10 loss: 1.9901624917984009 acc: 0.38 correct: tensor(38, device='cuda:0')
# epoch 12 # 15 loss: 1.891737699508667 acc: 0.44 correct: tensor(44, device='cuda:0')
# epoch 12 # 20 loss: 2.014930486679077 acc: 0.35 correct: tensor(35, device='cuda:0')
# epoch 13 # 0 loss: 1.7090187072753906 acc: 0.46 correct: tensor(46, device='cuda:0')
# epoch 13 # 5 loss: 1.8883405923843384 acc: 0.34 correct: tensor(34, device='cuda:0')
# epoch 13 # 10 loss: 2.0028879642486572 acc: 0.35 correct: tensor(35, device='cuda:0')
# epoch 13 # 15 loss: 2.1114842891693115 acc: 0.23 correct: tensor(23, device='cuda:0')
# epoch 13 # 20 loss: 1.9891928434371948 acc: 0.36 correct: tensor(36, device='cuda:0')
# epoch 14 # 0 loss: 1.7790696620941162 acc: 0.37 correct: tensor(37, device='cuda:0')
# epoch 14 # 5 loss: 1.8547084331512451 acc: 0.42 correct: tensor(42, device='cuda:0')
# epoch 14 # 10 loss: 1.966109037399292 acc: 0.34 correct: tensor(34, device='cuda:0')
# epoch 14 # 15 loss: 1.9710626602172852 acc: 0.29 correct: tensor(29, device='cuda:0')
# epoch 14 # 20 loss: 2.0746212005615234 acc: 0.3 correct: tensor(30, device='cuda:0')
# epoch 15 # 0 loss: 1.6905732154846191 acc: 0.42 correct: tensor(42, device='cuda:0')
# epoch 15 # 5 loss: 1.8893890380859375 acc: 0.38 correct: tensor(38, device='cuda:0')
# epoch 15 # 10 loss: 1.8788200616836548 acc: 0.43 correct: tensor(43, device='cuda:0')
# epoch 15 # 15 loss: 1.981310248374939 acc: 0.31 correct: tensor(31, device='cuda:0')
# epoch 15 # 20 loss: 2.0224008560180664 acc: 0.37 correct: tensor(37, device='cuda:0')
# epoch 16 # 0 loss: 1.8374731540679932 acc: 0.39 correct: tensor(39, device='cuda:0')
# epoch 16 # 5 loss: 1.6994616985321045 acc: 0.35 correct: tensor(35, device='cuda:0')
# epoch 16 # 10 loss: 1.8021517992019653 acc: 0.4 correct: tensor(40, device='cuda:0')
# epoch 16 # 15 loss: 2.013618230819702 acc: 0.29 correct: tensor(29, device='cuda:0')
# epoch 16 # 20 loss: 1.8756037950515747 acc: 0.31 correct: tensor(31, device='cuda:0')
# epoch 17 # 0 loss: 1.6456929445266724 acc: 0.42 correct: tensor(42, device='cuda:0')
# epoch 17 # 5 loss: 1.5557011365890503 acc: 0.45 correct: tensor(45, device='cuda:0')
# epoch 17 # 10 loss: 1.7657769918441772 acc: 0.43 correct: tensor(43, device='cuda:0')
# epoch 17 # 15 loss: 1.6843669414520264 acc: 0.44 correct: tensor(44, device='cuda:0')
# epoch 17 # 20 loss: 1.9219664335250854 acc: 0.34 correct: tensor(34, device='cuda:0')
# epoch 18 # 0 loss: 1.2972317934036255 acc: 0.61 correct: tensor(61, device='cuda:0')
# epoch 18 # 5 loss: 1.5771043300628662 acc: 0.53 correct: tensor(53, device='cuda:0')
# epoch 18 # 10 loss: 1.6351498365402222 acc: 0.43 correct: tensor(43, device='cuda:0')
# epoch 18 # 15 loss: 1.6856166124343872 acc: 0.39 correct: tensor(39, device='cuda:0')
# epoch 18 # 20 loss: 1.7121559381484985 acc: 0.38 correct: tensor(38, device='cuda:0')
# epoch 19 # 0 loss: 1.5069736242294312 acc: 0.46 correct: tensor(46, device='cuda:0')
# epoch 19 # 5 loss: 1.5443484783172607 acc: 0.5 correct: tensor(50, device='cuda:0')
# epoch 19 # 10 loss: 1.667697787284851 acc: 0.33 correct: tensor(33, device='cuda:0')
# epoch 19 # 15 loss: 1.6684670448303223 acc: 0.42 correct: tensor(42, device='cuda:0')
# epoch 19 # 20 loss: 1.7354285717010498 acc: 0.42 correct: tensor(42, device='cuda:0')
# epoch 20 # 0 loss: 1.5425026416778564 acc: 0.45 correct: tensor(45, device='cuda:0')
# epoch 20 # 5 loss: 1.5044376850128174 acc: 0.51 correct: tensor(51, device='cuda:0')
# epoch 20 # 10 loss: 1.508642315864563 acc: 0.5 correct: tensor(50, device='cuda:0')
# epoch 20 # 15 loss: 1.7707328796386719 acc: 0.33 correct: tensor(33, device='cuda:0')
# epoch 20 # 20 loss: 1.6995759010314941 acc: 0.38 correct: tensor(38, device='cuda:0')
# epoch 21 # 0 loss: 1.2021726369857788 acc: 0.67 correct: tensor(67, device='cuda:0')
# epoch 21 # 5 loss: 1.4757378101348877 acc: 0.45 correct: tensor(45, device='cuda:0')
# epoch 21 # 10 loss: 1.4087631702423096 acc: 0.54 correct: tensor(54, device='cuda:0')
# epoch 21 # 15 loss: 1.678236722946167 acc: 0.41 correct: tensor(41, device='cuda:0')
# epoch 21 # 20 loss: 1.571150541305542 acc: 0.4 correct: tensor(40, device='cuda:0')
# epoch 22 # 0 loss: 1.383175015449524 acc: 0.5 correct: tensor(50, device='cuda:0')
# epoch 22 # 5 loss: 1.342108964920044 acc: 0.57 correct: tensor(57, device='cuda:0')
# epoch 22 # 10 loss: 1.3201316595077515 acc: 0.57 correct: tensor(57, device='cuda:0')
# epoch 22 # 15 loss: 1.5581068992614746 acc: 0.46 correct: tensor(46, device='cuda:0')
# epoch 22 # 20 loss: 1.6337051391601562 acc: 0.38 correct: tensor(38, device='cuda:0')
# epoch 23 # 0 loss: 1.2111283540725708 acc: 0.63 correct: tensor(63, device='cuda:0')
# epoch 23 # 5 loss: 1.3854327201843262 acc: 0.46 correct: tensor(46, device='cuda:0')
# epoch 23 # 10 loss: 1.6250582933425903 acc: 0.44 correct: tensor(44, device='cuda:0')
# epoch 23 # 15 loss: 1.5319637060165405 acc: 0.49 correct: tensor(49, device='cuda:0')
# epoch 23 # 20 loss: 1.5748693943023682 acc: 0.4 correct: tensor(40, device='cuda:0')
# epoch 24 # 0 loss: 1.2227920293807983 acc: 0.61 correct: tensor(61, device='cuda:0')
# epoch 24 # 5 loss: 1.414818286895752 acc: 0.55 correct: tensor(55, device='cuda:0')
# epoch 24 # 10 loss: 1.2244043350219727 acc: 0.58 correct: tensor(58, device='cuda:0')
# epoch 24 # 15 loss: 1.6234159469604492 acc: 0.46 correct: tensor(46, device='cuda:0')
# epoch 24 # 20 loss: 1.5087741613388062 acc: 0.47 correct: tensor(47, device='cuda:0')
# epoch 25 # 0 loss: 1.1372427940368652 acc: 0.61 correct: tensor(61, device='cuda:0')
# epoch 25 # 5 loss: 1.274889349937439 acc: 0.57 correct: tensor(57, device='cuda:0')
# epoch 25 # 10 loss: 1.3111556768417358 acc: 0.49 correct: tensor(49, device='cuda:0')
# epoch 25 # 15 loss: 1.4773887395858765 acc: 0.51 correct: tensor(51, device='cuda:0')
# epoch 25 # 20 loss: 1.5750906467437744 acc: 0.4 correct: tensor(40, device='cuda:0')
# epoch 26 # 0 loss: 1.200526475906372 acc: 0.52 correct: tensor(52, device='cuda:0')
# epoch 26 # 5 loss: 1.106431007385254 acc: 0.61 correct: tensor(61, device='cuda:0')
# epoch 26 # 10 loss: 1.2545901536941528 acc: 0.56 correct: tensor(56, device='cuda:0')
# epoch 26 # 15 loss: 1.3680026531219482 acc: 0.45 correct: tensor(45, device='cuda:0')
# epoch 26 # 20 loss: 1.4804800748825073 acc: 0.46 correct: tensor(46, device='cuda:0')
# epoch 27 # 0 loss: 1.0131691694259644 acc: 0.63 correct: tensor(63, device='cuda:0')
# epoch 27 # 5 loss: 1.17177152633667 acc: 0.65 correct: tensor(65, device='cuda:0')
# epoch 27 # 10 loss: 1.1268051862716675 acc: 0.53 correct: tensor(53, device='cuda:0')
# epoch 27 # 15 loss: 1.2200138568878174 acc: 0.62 correct: tensor(62, device='cuda:0')
# epoch 27 # 20 loss: 1.2582550048828125 acc: 0.58 correct: tensor(58, device='cuda:0')
# epoch 28 # 0 loss: 1.0177662372589111 acc: 0.68 correct: tensor(68, device='cuda:0')
# epoch 28 # 5 loss: 1.1696391105651855 acc: 0.56 correct: tensor(56, device='cuda:0')
# epoch 28 # 10 loss: 1.2467535734176636 acc: 0.57 correct: tensor(57, device='cuda:0')
# epoch 28 # 15 loss: 1.258487582206726 acc: 0.62 correct: tensor(62, device='cuda:0')
# epoch 28 # 20 loss: 1.2831521034240723 acc: 0.53 correct: tensor(53, device='cuda:0')
# epoch 29 # 0 loss: 1.019792914390564 acc: 0.67 correct: tensor(67, device='cuda:0')
# epoch 29 # 5 loss: 1.0105935335159302 acc: 0.69 correct: tensor(69, device='cuda:0')
# epoch 29 # 10 loss: 1.1706104278564453 acc: 0.6 correct: tensor(60, device='cuda:0')
# epoch 29 # 15 loss: 1.1680035591125488 acc: 0.55 correct: tensor(55, device='cuda:0')
# epoch 29 # 20 loss: 1.058895468711853 acc: 0.65 correct: tensor(65, device='cuda:0')
# epoch 30 # 0 loss: 1.0596153736114502 acc: 0.66 correct: tensor(66, device='cuda:0')
# epoch 30 # 5 loss: 1.146895408630371 acc: 0.64 correct: tensor(64, device='cuda:0')
# epoch 30 # 10 loss: 1.1647789478302002 acc: 0.65 correct: tensor(65, device='cuda:0')
# epoch 30 # 15 loss: 1.2019829750061035 acc: 0.55 correct: tensor(55, device='cuda:0')
# epoch 30 # 20 loss: 1.1692194938659668 acc: 0.59 correct: tensor(59, device='cuda:0')
# epoch 31 # 0 loss: 0.9464433193206787 acc: 0.71 correct: tensor(71, device='cuda:0')
# epoch 31 # 5 loss: 0.9931949377059937 acc: 0.68 correct: tensor(68, device='cuda:0')
# epoch 31 # 10 loss: 1.2452794313430786 acc: 0.51 correct: tensor(51, device='cuda:0')
# epoch 31 # 15 loss: 0.9714150428771973 acc: 0.7 correct: tensor(70, device='cuda:0')
# epoch 31 # 20 loss: 1.246504545211792 acc: 0.56 correct: tensor(56, device='cuda:0')
# epoch 32 # 0 loss: 0.789071261882782 acc: 0.77 correct: tensor(77, device='cuda:0')
# epoch 32 # 5 loss: 1.0046621561050415 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 32 # 10 loss: 1.0147403478622437 acc: 0.64 correct: tensor(64, device='cuda:0')
# epoch 32 # 15 loss: 1.185107707977295 acc: 0.58 correct: tensor(58, device='cuda:0')
# epoch 32 # 20 loss: 1.0421675443649292 acc: 0.62 correct: tensor(62, device='cuda:0')
# epoch 33 # 0 loss: 0.9175498485565186 acc: 0.73 correct: tensor(73, device='cuda:0')
# epoch 33 # 5 loss: 1.164801836013794 acc: 0.65 correct: tensor(65, device='cuda:0')
# epoch 33 # 10 loss: 0.8989229798316956 acc: 0.67 correct: tensor(67, device='cuda:0')
# epoch 33 # 15 loss: 0.9744894504547119 acc: 0.69 correct: tensor(69, device='cuda:0')
# epoch 33 # 20 loss: 1.1808192729949951 acc: 0.61 correct: tensor(61, device='cuda:0')
# epoch 34 # 0 loss: 0.8599065542221069 acc: 0.72 correct: tensor(72, device='cuda:0')
# epoch 34 # 5 loss: 0.8783827424049377 acc: 0.7 correct: tensor(70, device='cuda:0')
# epoch 34 # 10 loss: 0.9538912773132324 acc: 0.66 correct: tensor(66, device='cuda:0')
# epoch 34 # 15 loss: 1.1584235429763794 acc: 0.58 correct: tensor(58, device='cuda:0')
# epoch 34 # 20 loss: 1.1709928512573242 acc: 0.6 correct: tensor(60, device='cuda:0')
# epoch 35 # 0 loss: 0.9385408163070679 acc: 0.74 correct: tensor(74, device='cuda:0')
# epoch 35 # 5 loss: 0.7972439527511597 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 35 # 10 loss: 0.8343407511711121 acc: 0.69 correct: tensor(69, device='cuda:0')
# epoch 35 # 15 loss: 1.0811963081359863 acc: 0.59 correct: tensor(59, device='cuda:0')
# epoch 35 # 20 loss: 1.0964030027389526 acc: 0.63 correct: tensor(63, device='cuda:0')
# epoch 36 # 0 loss: 0.7639834880828857 acc: 0.8 correct: tensor(80, device='cuda:0')
# epoch 36 # 5 loss: 0.8458011746406555 acc: 0.74 correct: tensor(74, device='cuda:0')
# epoch 36 # 10 loss: 0.9217810034751892 acc: 0.68 correct: tensor(68, device='cuda:0')
# epoch 36 # 15 loss: 0.8337385058403015 acc: 0.73 correct: tensor(73, device='cuda:0')
# epoch 36 # 20 loss: 0.8338080048561096 acc: 0.76 correct: tensor(76, device='cuda:0')
# epoch 37 # 0 loss: 0.7573356628417969 acc: 0.78 correct: tensor(78, device='cuda:0')
# epoch 37 # 5 loss: 0.8165353536605835 acc: 0.73 correct: tensor(73, device='cuda:0')
# epoch 37 # 10 loss: 0.995953381061554 acc: 0.69 correct: tensor(69, device='cuda:0')
# epoch 37 # 15 loss: 0.8808165788650513 acc: 0.69 correct: tensor(69, device='cuda:0')
# epoch 37 # 20 loss: 0.9482177495956421 acc: 0.69 correct: tensor(69, device='cuda:0')
# epoch 38 # 0 loss: 0.6682666540145874 acc: 0.79 correct: tensor(79, device='cuda:0')
# epoch 38 # 5 loss: 1.038689374923706 acc: 0.65 correct: tensor(65, device='cuda:0')
# epoch 38 # 10 loss: 0.8010292053222656 acc: 0.72 correct: tensor(72, device='cuda:0')
# epoch 38 # 15 loss: 0.8932777643203735 acc: 0.71 correct: tensor(71, device='cuda:0')
# epoch 38 # 20 loss: 0.9621162414550781 acc: 0.61 correct: tensor(61, device='cuda:0')
# epoch 39 # 0 loss: 0.6980197429656982 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 39 # 5 loss: 0.6326214671134949 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 39 # 10 loss: 0.8213253617286682 acc: 0.78 correct: tensor(78, device='cuda:0')
# epoch 39 # 15 loss: 0.752566397190094 acc: 0.76 correct: tensor(76, device='cuda:0')
# epoch 39 # 20 loss: 0.7343466281890869 acc: 0.79 correct: tensor(79, device='cuda:0')
# epoch 40 # 0 loss: 0.6849154829978943 acc: 0.78 correct: tensor(78, device='cuda:0')
# epoch 40 # 5 loss: 0.719596266746521 acc: 0.8 correct: tensor(80, device='cuda:0')
# epoch 40 # 10 loss: 0.7450883984565735 acc: 0.73 correct: tensor(73, device='cuda:0')
# epoch 40 # 15 loss: 0.739389955997467 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 40 # 20 loss: 0.855853796005249 acc: 0.67 correct: tensor(67, device='cuda:0')
# epoch 41 # 0 loss: 0.6285322904586792 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 41 # 5 loss: 0.7510371208190918 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 41 # 10 loss: 0.651943027973175 acc: 0.78 correct: tensor(78, device='cuda:0')
# epoch 41 # 15 loss: 0.600308895111084 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 41 # 20 loss: 0.9199044704437256 acc: 0.69 correct: tensor(69, device='cuda:0')
# epoch 42 # 0 loss: 0.6779240369796753 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 42 # 5 loss: 0.6721897125244141 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 42 # 10 loss: 0.9223630428314209 acc: 0.72 correct: tensor(72, device='cuda:0')
# epoch 42 # 15 loss: 0.8135599493980408 acc: 0.68 correct: tensor(68, device='cuda:0')
# epoch 42 # 20 loss: 0.8446241617202759 acc: 0.73 correct: tensor(73, device='cuda:0')
# epoch 43 # 0 loss: 0.6299843788146973 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 43 # 5 loss: 0.6627599596977234 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 43 # 10 loss: 0.7738010287284851 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 43 # 15 loss: 0.78693026304245 acc: 0.7 correct: tensor(70, device='cuda:0')
# epoch 43 # 20 loss: 0.7628070116043091 acc: 0.74 correct: tensor(74, device='cuda:0')
# epoch 44 # 0 loss: 0.49613118171691895 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 44 # 5 loss: 0.7282597422599792 acc: 0.73 correct: tensor(73, device='cuda:0')
# epoch 44 # 10 loss: 0.6332037448883057 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 44 # 15 loss: 0.7922165393829346 acc: 0.69 correct: tensor(69, device='cuda:0')
# epoch 44 # 20 loss: 0.7542348504066467 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 45 # 0 loss: 0.6248643398284912 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 45 # 5 loss: 0.5590567588806152 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 45 # 10 loss: 0.6878055334091187 acc: 0.76 correct: tensor(76, device='cuda:0')
# epoch 45 # 15 loss: 0.7347363829612732 acc: 0.72 correct: tensor(72, device='cuda:0')
# epoch 45 # 20 loss: 0.9503685235977173 acc: 0.69 correct: tensor(69, device='cuda:0')
# epoch 46 # 0 loss: 0.5887418389320374 acc: 0.8 correct: tensor(80, device='cuda:0')
# epoch 46 # 5 loss: 0.4340452253818512 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 46 # 10 loss: 0.5940104722976685 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 46 # 15 loss: 0.653066873550415 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 46 # 20 loss: 0.8165994882583618 acc: 0.68 correct: tensor(68, device='cuda:0')
# epoch 47 # 0 loss: 0.4179048240184784 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 47 # 5 loss: 0.717843234539032 acc: 0.78 correct: tensor(78, device='cuda:0')
# epoch 47 # 10 loss: 0.6041538715362549 acc: 0.78 correct: tensor(78, device='cuda:0')
# epoch 47 # 15 loss: 0.6687292456626892 acc: 0.77 correct: tensor(77, device='cuda:0')
# epoch 47 # 20 loss: 0.5662757158279419 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 48 # 0 loss: 0.5065121650695801 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 48 # 5 loss: 0.5481764674186707 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 48 # 10 loss: 0.7978978157043457 acc: 0.71 correct: tensor(71, device='cuda:0')
# epoch 48 # 15 loss: 0.6395284533500671 acc: 0.77 correct: tensor(77, device='cuda:0')
# epoch 48 # 20 loss: 0.8440624475479126 acc: 0.67 correct: tensor(67, device='cuda:0')
# epoch 49 # 0 loss: 0.5302809476852417 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 49 # 5 loss: 0.5490160584449768 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 49 # 10 loss: 0.6032519340515137 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 49 # 15 loss: 0.6954711675643921 acc: 0.7 correct: tensor(70, device='cuda:0')
# epoch 49 # 20 loss: 0.58526611328125 acc: 0.8 correct: tensor(80, device='cuda:0')
# epoch 50 # 0 loss: 0.5689905285835266 acc: 0.78 correct: tensor(78, device='cuda:0')
# epoch 50 # 5 loss: 0.5299743413925171 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 50 # 10 loss: 0.7055824995040894 acc: 0.77 correct: tensor(77, device='cuda:0')
# epoch 50 # 15 loss: 0.6488077640533447 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 50 # 20 loss: 0.6089388728141785 acc: 0.78 correct: tensor(78, device='cuda:0')
# epoch 51 # 0 loss: 0.5159879922866821 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 51 # 5 loss: 0.4914170205593109 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 51 # 10 loss: 0.4915686845779419 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 51 # 15 loss: 0.6439769864082336 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 51 # 20 loss: 0.6893243193626404 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 52 # 0 loss: 0.411268949508667 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 52 # 5 loss: 0.5849229097366333 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 52 # 10 loss: 0.6270044445991516 acc: 0.76 correct: tensor(76, device='cuda:0')
# epoch 52 # 15 loss: 0.6321979761123657 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 52 # 20 loss: 0.6639434099197388 acc: 0.76 correct: tensor(76, device='cuda:0')
# epoch 53 # 0 loss: 0.4647953510284424 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 53 # 5 loss: 0.4967353045940399 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 53 # 10 loss: 0.4872925281524658 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 53 # 15 loss: 0.4789133369922638 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 53 # 20 loss: 0.6981179118156433 acc: 0.8 correct: tensor(80, device='cuda:0')
# epoch 54 # 0 loss: 0.596299946308136 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 54 # 5 loss: 0.5795385837554932 acc: 0.8 correct: tensor(80, device='cuda:0')
# epoch 54 # 10 loss: 0.3336227536201477 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 54 # 15 loss: 0.47286903858184814 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 54 # 20 loss: 0.43395182490348816 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 55 # 0 loss: 0.5160356760025024 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 55 # 5 loss: 0.46832475066185 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 55 # 10 loss: 0.5308090448379517 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 55 # 15 loss: 0.42040908336639404 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 55 # 20 loss: 0.5291973948478699 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 56 # 0 loss: 0.5354011654853821 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 56 # 5 loss: 0.45081520080566406 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 56 # 10 loss: 0.5566732287406921 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 56 # 15 loss: 0.46374207735061646 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 56 # 20 loss: 0.683363676071167 acc: 0.77 correct: tensor(77, device='cuda:0')
# epoch 57 # 0 loss: 0.33186671137809753 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 57 # 5 loss: 0.49712151288986206 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 57 # 10 loss: 0.47148123383522034 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 57 # 15 loss: 0.4394626319408417 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 57 # 20 loss: 0.4616658687591553 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 58 # 0 loss: 0.6494892239570618 acc: 0.75 correct: tensor(75, device='cuda:0')
# epoch 58 # 5 loss: 0.4529047906398773 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 58 # 10 loss: 0.5421764850616455 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 58 # 15 loss: 0.43428608775138855 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 58 # 20 loss: 0.684364914894104 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 59 # 0 loss: 0.2962620258331299 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 59 # 5 loss: 0.44623467326164246 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 59 # 10 loss: 0.46938326954841614 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 59 # 15 loss: 0.48703157901763916 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 59 # 20 loss: 0.5443760752677917 acc: 0.78 correct: tensor(78, device='cuda:0')
# epoch 60 # 0 loss: 0.40606072545051575 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 60 # 5 loss: 0.4483431279659271 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 60 # 10 loss: 0.39580902457237244 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 60 # 15 loss: 0.3504348695278168 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 60 # 20 loss: 0.4823659658432007 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 61 # 0 loss: 0.4834601581096649 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 61 # 5 loss: 0.37754181027412415 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 61 # 10 loss: 0.4017869532108307 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 61 # 15 loss: 0.46757450699806213 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 61 # 20 loss: 0.43219199776649475 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 62 # 0 loss: 0.3112848401069641 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 62 # 5 loss: 0.4213626980781555 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 62 # 10 loss: 0.5215931534767151 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 62 # 15 loss: 0.503070592880249 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 62 # 20 loss: 0.45024651288986206 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 63 # 0 loss: 0.26782333850860596 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 63 # 5 loss: 0.3139329254627228 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 63 # 10 loss: 0.5039041638374329 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 63 # 15 loss: 0.42147037386894226 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 63 # 20 loss: 0.6172472238540649 acc: 0.77 correct: tensor(77, device='cuda:0')
# epoch 64 # 0 loss: 0.358323335647583 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 64 # 5 loss: 0.4635930359363556 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 64 # 10 loss: 0.5044583678245544 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 64 # 15 loss: 0.4169912040233612 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 64 # 20 loss: 0.49250534176826477 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 65 # 0 loss: 0.367715060710907 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 65 # 5 loss: 0.32316410541534424 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 65 # 10 loss: 0.41124871373176575 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 65 # 15 loss: 0.41423606872558594 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 65 # 20 loss: 0.4978550672531128 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 66 # 0 loss: 0.3382323384284973 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 66 # 5 loss: 0.32516777515411377 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 66 # 10 loss: 0.4424726068973541 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 66 # 15 loss: 0.4025731682777405 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 66 # 20 loss: 0.498534619808197 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 67 # 0 loss: 0.2626192569732666 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 67 # 5 loss: 0.3189820647239685 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 67 # 10 loss: 0.46856993436813354 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 67 # 15 loss: 0.4939635992050171 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 67 # 20 loss: 0.4532991647720337 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 68 # 0 loss: 0.3258582353591919 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 68 # 5 loss: 0.3083259165287018 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 68 # 10 loss: 0.5336125493049622 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 68 # 15 loss: 0.40236160159111023 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 68 # 20 loss: 0.3895809054374695 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 69 # 0 loss: 0.2612447440624237 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 69 # 5 loss: 0.319039911031723 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 69 # 10 loss: 0.40295639634132385 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 69 # 15 loss: 0.3343803286552429 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 69 # 20 loss: 0.4427204132080078 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 70 # 0 loss: 0.3643210232257843 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 70 # 5 loss: 0.36632001399993896 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 70 # 10 loss: 0.3127581775188446 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 70 # 15 loss: 0.3688078224658966 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 70 # 20 loss: 0.44868001341819763 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 71 # 0 loss: 0.2963006794452667 acc: 0.95 correct: tensor(95, device='cuda:0')
# epoch 71 # 5 loss: 0.3700138330459595 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 71 # 10 loss: 0.2965003252029419 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 71 # 15 loss: 0.47788092494010925 acc: 0.82 correct: tensor(82, device='cuda:0')
# epoch 71 # 20 loss: 0.43796250224113464 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 72 # 0 loss: 0.2368413209915161 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 72 # 5 loss: 0.3346949815750122 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 72 # 10 loss: 0.36934661865234375 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 72 # 15 loss: 0.5710022449493408 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 72 # 20 loss: 0.4201579988002777 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 73 # 0 loss: 0.2726908028125763 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 73 # 5 loss: 0.3415791988372803 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 73 # 10 loss: 0.31451261043548584 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 73 # 15 loss: 0.38193169236183167 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 73 # 20 loss: 0.5881770849227905 acc: 0.77 correct: tensor(77, device='cuda:0')
# epoch 74 # 0 loss: 0.24749794602394104 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 74 # 5 loss: 0.22025686502456665 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 74 # 10 loss: 0.34688812494277954 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 74 # 15 loss: 0.29379725456237793 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 74 # 20 loss: 0.35460856556892395 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 75 # 0 loss: 0.1724017858505249 acc: 0.96 correct: tensor(96, device='cuda:0')
# epoch 75 # 5 loss: 0.23445087671279907 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 75 # 10 loss: 0.468351811170578 acc: 0.8 correct: tensor(80, device='cuda:0')
# epoch 75 # 15 loss: 0.47165948152542114 acc: 0.81 correct: tensor(81, device='cuda:0')
# epoch 75 # 20 loss: 0.44355449080467224 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 76 # 0 loss: 0.319863885641098 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 76 # 5 loss: 0.3587455749511719 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 76 # 10 loss: 0.2541444003582001 acc: 0.95 correct: tensor(95, device='cuda:0')
# epoch 76 # 15 loss: 0.36557307839393616 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 76 # 20 loss: 0.390634149312973 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 77 # 0 loss: 0.20009642839431763 acc: 0.95 correct: tensor(95, device='cuda:0')
# epoch 77 # 5 loss: 0.2702895998954773 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 77 # 10 loss: 0.3238462805747986 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 77 # 15 loss: 0.42533087730407715 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 77 # 20 loss: 0.3304823040962219 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 78 # 0 loss: 0.28064849972724915 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 78 # 5 loss: 0.2780633270740509 acc: 0.95 correct: tensor(95, device='cuda:0')
# epoch 78 # 10 loss: 0.21677826344966888 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 78 # 15 loss: 0.4209897518157959 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 78 # 20 loss: 0.39118728041648865 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 79 # 0 loss: 0.32854655385017395 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 79 # 5 loss: 0.26387882232666016 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 79 # 10 loss: 0.39626070857048035 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 79 # 15 loss: 0.30970442295074463 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 79 # 20 loss: 0.43087852001190186 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 80 # 0 loss: 0.2647538483142853 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 80 # 5 loss: 0.2656800150871277 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 80 # 10 loss: 0.2682524621486664 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 80 # 15 loss: 0.46512752771377563 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 80 # 20 loss: 0.28295180201530457 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 81 # 0 loss: 0.23018020391464233 acc: 0.96 correct: tensor(96, device='cuda:0')
# epoch 81 # 5 loss: 0.26866093277931213 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 81 # 10 loss: 0.20486584305763245 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 81 # 15 loss: 0.3521021008491516 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 81 # 20 loss: 0.48882970213890076 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 82 # 0 loss: 0.2334917038679123 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 82 # 5 loss: 0.29688507318496704 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 82 # 10 loss: 0.34459513425827026 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 82 # 15 loss: 0.2246716469526291 acc: 0.95 correct: tensor(95, device='cuda:0')
# epoch 82 # 20 loss: 0.3109245300292969 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 83 # 0 loss: 0.20757701992988586 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 83 # 5 loss: 0.21278661489486694 acc: 0.96 correct: tensor(96, device='cuda:0')
# epoch 83 # 10 loss: 0.4421340227127075 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 83 # 15 loss: 0.2501942813396454 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 83 # 20 loss: 0.3495452105998993 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 84 # 0 loss: 0.20621654391288757 acc: 0.95 correct: tensor(95, device='cuda:0')
# epoch 84 # 5 loss: 0.3516668677330017 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 84 # 10 loss: 0.37821319699287415 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 84 # 15 loss: 0.37403061985969543 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 84 # 20 loss: 0.4435141086578369 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 85 # 0 loss: 0.36858052015304565 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 85 # 5 loss: 0.4234185516834259 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 85 # 10 loss: 0.24018920958042145 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 85 # 15 loss: 0.32069069147109985 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 85 # 20 loss: 0.4521147906780243 acc: 0.8 correct: tensor(80, device='cuda:0')
# epoch 86 # 0 loss: 0.2952533960342407 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 86 # 5 loss: 0.27844345569610596 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 86 # 10 loss: 0.23135237395763397 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 86 # 15 loss: 0.44958728551864624 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 86 # 20 loss: 0.35427483916282654 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 87 # 0 loss: 0.2652911841869354 acc: 0.95 correct: tensor(95, device='cuda:0')
# epoch 87 # 5 loss: 0.3287564814090729 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 87 # 10 loss: 0.38591456413269043 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 87 # 15 loss: 0.26786568760871887 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 87 # 20 loss: 0.31537383794784546 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 88 # 0 loss: 0.26080620288848877 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 88 # 5 loss: 0.25740501284599304 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 88 # 10 loss: 0.2508513927459717 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 88 # 15 loss: 0.29348134994506836 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 88 # 20 loss: 0.3598642349243164 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 89 # 0 loss: 0.26549649238586426 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 89 # 5 loss: 0.3654318153858185 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 89 # 10 loss: 0.2669873833656311 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 89 # 15 loss: 0.2545597553253174 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 89 # 20 loss: 0.3888167142868042 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 90 # 0 loss: 0.3912982642650604 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 90 # 5 loss: 0.2318417727947235 acc: 0.96 correct: tensor(96, device='cuda:0')
# epoch 90 # 10 loss: 0.3476497530937195 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 90 # 15 loss: 0.34948140382766724 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 90 # 20 loss: 0.34015074372291565 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 91 # 0 loss: 0.3413284420967102 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 91 # 5 loss: 0.4332149624824524 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 91 # 10 loss: 0.26163002848625183 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 91 # 15 loss: 0.22423262894153595 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 91 # 20 loss: 0.2498561441898346 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 92 # 0 loss: 0.35601818561553955 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 92 # 5 loss: 0.21318362653255463 acc: 0.96 correct: tensor(96, device='cuda:0')
# epoch 92 # 10 loss: 0.30247703194618225 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 92 # 15 loss: 0.23545730113983154 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 92 # 20 loss: 0.21089446544647217 acc: 0.95 correct: tensor(95, device='cuda:0')
# epoch 93 # 0 loss: 0.2559674382209778 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 93 # 5 loss: 0.26372161507606506 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 93 # 10 loss: 0.30721548199653625 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 93 # 15 loss: 0.242905393242836 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 93 # 20 loss: 0.32578757405281067 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 94 # 0 loss: 0.1992218792438507 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 94 # 5 loss: 0.3084988296031952 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 94 # 10 loss: 0.19223548471927643 acc: 0.95 correct: tensor(95, device='cuda:0')
# epoch 94 # 15 loss: 0.2866167426109314 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 94 # 20 loss: 0.43367400765419006 acc: 0.88 correct: tensor(88, device='cuda:0')
# epoch 95 # 0 loss: 0.2582552134990692 acc: 0.91 correct: tensor(91, device='cuda:0')
# epoch 95 # 5 loss: 0.2050141841173172 acc: 0.96 correct: tensor(96, device='cuda:0')
# epoch 95 # 10 loss: 0.35771191120147705 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 95 # 15 loss: 0.21870598196983337 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 95 # 20 loss: 0.32466232776641846 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 96 # 0 loss: 0.20609264075756073 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 96 # 5 loss: 0.20719021558761597 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 96 # 10 loss: 0.2794151306152344 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 96 # 15 loss: 0.37357544898986816 acc: 0.87 correct: tensor(87, device='cuda:0')
# epoch 96 # 20 loss: 0.4145592451095581 acc: 0.84 correct: tensor(84, device='cuda:0')
# epoch 97 # 0 loss: 0.21140386164188385 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 97 # 5 loss: 0.2358822226524353 acc: 0.93 correct: tensor(93, device='cuda:0')
# epoch 97 # 10 loss: 0.353400319814682 acc: 0.89 correct: tensor(89, device='cuda:0')
# epoch 97 # 15 loss: 0.4282393753528595 acc: 0.86 correct: tensor(86, device='cuda:0')
# epoch 97 # 20 loss: 0.2998490631580353 acc: 0.9 correct: tensor(90, device='cuda:0')
# epoch 98 # 0 loss: 0.34494537115097046 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 98 # 5 loss: 0.1982165277004242 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 98 # 10 loss: 0.4198906719684601 acc: 0.83 correct: tensor(83, device='cuda:0')
# epoch 98 # 15 loss: 0.25699955224990845 acc: 0.94 correct: tensor(94, device='cuda:0')
# epoch 98 # 20 loss: 0.29054683446884155 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 99 # 0 loss: 0.23732605576515198 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 99 # 5 loss: 0.28913676738739014 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 99 # 10 loss: 0.39899131655693054 acc: 0.85 correct: tensor(85, device='cuda:0')
# epoch 99 # 15 loss: 0.2883101999759674 acc: 0.92 correct: tensor(92, device='cuda:0')
# epoch 99 # 20 loss: 0.2626400291919708 acc: 0.95 correct: tensor(95, device='cuda:0')
#
#  TEST
#
# epoch 99 # 0 loss: 11.519109725952148 acc: 0.2 correct: tensor(1, device='cuda:0')
# epoch 99 # 5 loss: 5.4386467933654785 acc: 0.4 correct: tensor(2, device='cuda:0')
# epoch 99 # 10 loss: 7.627737522125244 acc: 0.2 correct: tensor(1, device='cuda:0')
# epoch 99 # 15 loss: 6.835701942443848 acc: 0.2 correct: tensor(1, device='cuda:0')
# epoch 99 # 20 loss: 7.778101444244385 acc: 0.2 correct: tensor(1, device='cuda:0')
# epoch 99 # 25 loss: 10.558191299438477 acc: 0.0 correct: tensor(0, device='cuda:0')
# epoch 99 # 30 loss: 9.531694412231445 acc: 0.0 correct: tensor(0, device='cuda:0')
# epoch 99 # 35 loss: 15.770599365234375 acc: 0.2 correct: tensor(1, device='cuda:0')
# epoch 99 # 40 loss: 10.22923469543457 acc: 0.0 correct: tensor(0, device='cuda:0')
# epoch 99 # 45 loss: 6.204267978668213 acc: 0.2 correct: tensor(1, device='cuda:0')
# epoch 99 # 50 loss: 5.908519268035889 acc: 0.2 correct: tensor(1, device='cuda:0')
# epoch 99 # 55 loss: 7.7726054191589355 acc: 0.2 correct: tensor(1, device='cuda:0')

# %%
plt.figure()
plt.plot(range(len(lossList)), lossList, 'ro')
plt.show()

plt.figure()
plt.plot(range(len(accList)), accList, 'ro')
plt.show()

plt.figure()
plt.plot(range(len(accList_test)), accList_test, 'bo')
plt.show()

plt.figure()
plt.plot(range(len(accList_test)), accList_test, 'bo')
plt.show()
